# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Adit harde**
# student

# %% [markdown]
# I am interested in data science because,Data Science is evolving quickly because of the increasing demand of data around the world. Data scientists have a wide variety of skill sets that can leverage data and information to help organizations to make better strategic decisions

# %% [markdown]
# ### Addition of two numbers

# %%
1+1
# Out:
# 2

# %% [markdown]
# ### Groceries
# Tomato
# onion
# raddish

# %%
https://www.google.com/search?q=ibm+images&sxsrf=ALeKk03-xvY2SAE6Ryb9Ae24vANZtT1SIA:1588867251844&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjKq5Dhj6LpAhWtILcAHTgTA7MQ_AUoAXoECA8QAw&biw=1536&bih=722#imgrc=KTM5fQ5hgKCfjM

# %%
<img src="smiley.gif" alt="Smiley face" height="42" width="42">
